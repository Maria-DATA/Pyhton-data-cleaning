# %%
import seaborn as sns
import pandas as pd
import numpy as np
from pandas import DataFrame


df=pd.read_csv(r'C:\Users\drmar\Downloads\ExportCSV.csv')
df.head()  #data
# Out:
#    ID              Job Title                 Email Address FirstName LastName  \
# 0   1               Operator   Nina_Gonzales610@iatim.tech      Nina Gonzales
# 1   2              Inspector     Dakota_Rose6376@atink.com        Dakota Rose
# 2   3  Healthcare Specialist  Caleb_Ballard1884@sveldo.biz      Caleb Ballard
# 3   4         HR Coordinator  Adeline_Selby3048@elnee.tech      Adeline Selby
# 4   5              Treasurer   Adela_Farmer1000@gembat.biz       Adela Farmer
#
#   Date And Time
# 0     6/21/9896
# 1      9/6/9482
# 2     5/15/4609
# 3      7/5/3959
# 4     4/10/2671

# %%
for col in df.columns:
    missing_percent=np.mean(df[col].isnull())
    print('{}-{}%'.format(col,missing_percent))
# Out:
# ID-0.0%
# Job Title-0.0%
# Email Address-0.0%
# FirstName LastName-0.0%
# Date And Time-0.0%

# %%
df.dtypes # or can change datatype using df['col_name']=df['col_name'].astype('int64')wherever needed or to object
# Out:
# ID                     int64
# Job Title             object
# Email Address         object
# FirstName LastName    object
# Date And Time         object
# dtype: object

# %%
df.head()

df['last'] = [f"{name.split(' ')[1]}"for name in df['FirstName LastName']]

df.head()
# Out:
#    ID              Job Title                 Email Address FirstName LastName  \
# 0   1               Operator   Nina_Gonzales610@iatim.tech      Nina Gonzales
# 1   2              Inspector     Dakota_Rose6376@atink.com        Dakota Rose
# 2   3  Healthcare Specialist  Caleb_Ballard1884@sveldo.biz      Caleb Ballard
# 3   4         HR Coordinator  Adeline_Selby3048@elnee.tech      Adeline Selby
# 4   5              Treasurer   Adela_Farmer1000@gembat.biz       Adela Farmer
#
#   Date And Time      last
# 0     6/21/9896  Gonzales
# 1      9/6/9482      Rose
# 2     5/15/4609   Ballard
# 3      7/5/3959     Selby
# 4     4/10/2671    Farmer

# %%
df.head()

df['last'] = [f"{name.split(' ')[1]}"for name in df['FirstName LastName']]

df.head()
# Out:
#    ID              Job Title                 Email Address FirstName LastName  \
# 0   1               Operator   Nina_Gonzales610@iatim.tech      Nina Gonzales
# 1   2              Inspector     Dakota_Rose6376@atink.com        Dakota Rose
# 2   3  Healthcare Specialist  Caleb_Ballard1884@sveldo.biz      Caleb Ballard
# 3   4         HR Coordinator  Adeline_Selby3048@elnee.tech      Adeline Selby
# 4   5              Treasurer   Adela_Farmer1000@gembat.biz       Adela Farmer
#
#   Date And Time      last
# 0     6/21/9896  Gonzales
# 1      9/6/9482      Rose
# 2     5/15/4609   Ballard
# 3      7/5/3959     Selby
# 4     4/10/2671    Farmer

# %%
df.dtypes
# Out:
# ID                     int64
# Job Title             object
# Email Address         object
# FirstName LastName    object
# Date And Time         object
# last                  object
# dtype: object

# %%
df.sort_values(by=['ID'],inplace=False,ascending=False)
# Out:
#      ID              Job Title                    Email Address  \
# 99  100       IT Support Staff         Sarah_Rowe4894@twace.org
# 98   99     Executive Director  Amelia_Robertson9778@nimogy.biz
# 97   98        Business Broker          Elle_Cork1046@gmail.com
# 96   97        Assistant Buyer        Brad_Tyler5348@muall.tech
# 95   96         HR Coordinator      Drew_Thomson9215@sveldo.biz
# ..  ...                    ...                              ...
# 4     5              Treasurer      Adela_Farmer1000@gembat.biz
# 3     4         HR Coordinator     Adeline_Selby3048@elnee.tech
# 2     3  Healthcare Specialist     Caleb_Ballard1884@sveldo.biz
# 1     2              Inspector        Dakota_Rose6376@atink.com
# 0     1               Operator      Nina_Gonzales610@iatim.tech
#
#    FirstName LastName Date And Time       last
# 99         Sarah Rowe     8/30/6185       Rowe
# 98   Amelia Robertson      4/4/6535  Robertson
# 97          Elle Cork    10/27/7167       Cork
# ...

# %%
df.dtypes
# Out:
# ID                     int64
# Job Title             object
# Email Address         object
# FirstName LastName    object
# Date And Time         object
# last                  object
# dtype: object

# %%
df.head()
# Out:
#    ID              Job Title                 Email Address FirstName LastName  \
# 0   1               Operator   Nina_Gonzales610@iatim.tech      Nina Gonzales
# 1   2              Inspector     Dakota_Rose6376@atink.com        Dakota Rose
# 2   3  Healthcare Specialist  Caleb_Ballard1884@sveldo.biz      Caleb Ballard
# 3   4         HR Coordinator  Adeline_Selby3048@elnee.tech      Adeline Selby
# 4   5              Treasurer   Adela_Farmer1000@gembat.biz       Adela Farmer
#
#   Date And Time      last
# 0     6/21/9896  Gonzales
# 1      9/6/9482      Rose
# 2     5/15/4609   Ballard
# 3      7/5/3959     Selby
# 4     4/10/2671    Farmer

# %%
pd.set_option('display.max_rows',None)

# %%
df.sort_values(by=['ID'],inplace=False,ascending=False)
# Out:
#      ID                   Job Title                         Email Address  \
# 99  100            IT Support Staff              Sarah_Rowe4894@twace.org
# 98   99          Executive Director       Amelia_Robertson9778@nimogy.biz
# 97   98             Business Broker               Elle_Cork1046@gmail.com
# 96   97             Assistant Buyer             Brad_Tyler5348@muall.tech
# 95   96              HR Coordinator           Drew_Thomson9215@sveldo.biz
# 94   95              HR Coordinator       Danielle_Duvall7918@bulaffy.com
# 93   94                 Audiologist         Carter_Thompson258@fuliss.net
# 92   93             Design Engineer          Matt_Vaughan4856@cispeto.com
# 91   92  Call Center Representative             Doug_Abbey9857@ovock.tech
# 90   91             Assistant Buyer            Gloria_Michael4@nanoff.biz
# 89   90         Investment  Advisor             Maia_Ryan4690@ubusive.com
# 88   89                  Fabricator          Ronald_Jenkin4665@iatim.tech
# ...

# %%
df['ID'].drop_duplicates().sort_values(ascending=False)
# Out:
# 99    100
# 98     99
# 97     98
# 96     97
# 95     96
# 94     95
# 93     94
# 92     93
# 91     92
# 90     91
# 89     90
# 88     89
# 87     88
# 86     87
# 85     86
# 84     85
# 83     84
# 82     83
# 81     82
# 80     81
# 79     80
# 78     79
# 77     78
# 76     77
# 75     76
# 74     75
# 73     74
# 72     73
# 71     72
# 70     71
# 69     70
# 68     69
# 67     68
# 66     67
# 65     66
# 64     65
# 63     64
# 62     63
# 61     62
# 60     61
# 59     60
# 58     59
# 57     58
# 56     57
# 55     56
# 54     55
# 53     54
# 52     53
# 51     52
# 50     51
# 49     50
# 48     49
# 47     48
# 46     47
# 45     46
# 44     45
# 43     44
# 42     43
# 41     42
# 40     41
# 39     40
# 38     39
# 37     38
# 36     37
# 35     36
# 34     35
# 33     34
# 32     33
# 31     32
# 30     31
# 29     30
# 28     29
# 27     28
# 26     27
# 25     26
# 24     25
# 23     24
# 22     23
# 21     22
# 20     21
# 19     20
# 18     19
# 17     18
# ...

# %%
df['Email Address'].drop_duplicates().sort_values(ascending=True)
# Out:
# 51             Abdul_Holmes6213@supunk.biz
# 65            Abdul_Jackson6769@twipet.com
# 4              Adela_Farmer1000@gembat.biz
# 3             Adeline_Selby3048@elnee.tech
# 70            Alexander_Wise1652@qater.org
# 98         Amelia_Robertson9778@nimogy.biz
# 81              Anais_James6173@guentu.biz
# 84         Analise_Shelton6162@cispeto.com
# 87         Benjamin_Edwards6141@typill.biz
# 34              Brad_Rogers2172@eirey.tech
# 96               Brad_Tyler5348@muall.tech
# 2             Caleb_Ballard1884@sveldo.biz
# 24            Camila_Stanley8044@sheye.org
# 30        Candace_Blackburn5033@nimogy.biz
# 40            Carmella_Long2992@deons.tech
# 45             Carrie_Wright8319@vetan.org
# 10           Carter_Stewart8452@famism.biz
# 93           Carter_Thompson258@fuliss.net
# 49          Charlize_Farrow1880@nanoff.biz
# 16           Chester_Parker5781@mafthy.com
# 20         Chester_Quinnell2231@fuliss.net
# 1                Dakota_Rose6376@atink.com
# ...

# %%
df.drop_duplicates()
# Out:
#      ID                   Job Title                         Email Address  \
# 99  100            IT Support Staff              Sarah_Rowe4894@twace.org
# 98   99          Executive Director       Amelia_Robertson9778@nimogy.biz
# 97   98             Business Broker               Elle_Cork1046@gmail.com
# 96   97             Assistant Buyer             Brad_Tyler5348@muall.tech
# 95   96              HR Coordinator           Drew_Thomson9215@sveldo.biz
# 94   95              HR Coordinator       Danielle_Duvall7918@bulaffy.com
# 93   94                 Audiologist         Carter_Thompson258@fuliss.net
# 92   93             Design Engineer          Matt_Vaughan4856@cispeto.com
# 91   92  Call Center Representative             Doug_Abbey9857@ovock.tech
# 90   91             Assistant Buyer            Gloria_Michael4@nanoff.biz
# 89   90         Investment  Advisor             Maia_Ryan4690@ubusive.com
# 88   89                  Fabricator          Ronald_Jenkin4665@iatim.tech
# ...

# %%
len(df)
# Out:
# 100

# %%
df[df.columns[1]].count()#ignoring null values
# Out:
# 100

# %%
df.head()
# Out:
#      ID           Job Title                    Email Address  \
# 99  100    IT Support Staff         Sarah_Rowe4894@twace.org
# 98   99  Executive Director  Amelia_Robertson9778@nimogy.biz
# 97   98     Business Broker          Elle_Cork1046@gmail.com
# 96   97     Assistant Buyer        Brad_Tyler5348@muall.tech
# 95   96      HR Coordinator      Drew_Thomson9215@sveldo.biz
#
#    FirstName LastName Date And Time       last
# 99         Sarah Rowe     8/30/6185       Rowe
# 98   Amelia Robertson      4/4/6535  Robertson
# 97          Elle Cork    10/27/7167       Cork
# 96         Brad Tyler     1/28/7119      Tyler
# 95       Drew Thomson     6/27/6988    Thomson

# %%
df.head(10)
# Out:
#      ID                   Job Title                    Email Address  \
# 99  100            IT Support Staff         Sarah_Rowe4894@twace.org
# 98   99          Executive Director  Amelia_Robertson9778@nimogy.biz
# 97   98             Business Broker          Elle_Cork1046@gmail.com
# 96   97             Assistant Buyer        Brad_Tyler5348@muall.tech
# 95   96              HR Coordinator      Drew_Thomson9215@sveldo.biz
# 94   95              HR Coordinator  Danielle_Duvall7918@bulaffy.com
# 93   94                 Audiologist    Carter_Thompson258@fuliss.net
# 92   93             Design Engineer     Matt_Vaughan4856@cispeto.com
# 91   92  Call Center Representative        Doug_Abbey9857@ovock.tech
# 90   91             Assistant Buyer       Gloria_Michael4@nanoff.biz
#
#    FirstName LastName Date And Time       last
# 99         Sarah Rowe     8/30/6185       Rowe
# 98   Amelia Robertson      4/4/6535  Robertson
# 97          Elle Cork    10/27/7167       Cork
# ...

# %%
df.head(10)

# %%
df.drop(80)

# %%
df.head()

df['last'] = [f"{name.split(' ')[1]}"for name in df['FirstName LastName']]

df.head()
# Out:
#    ID              Job Title                 Email Address FirstName LastName  \
# 0   1               Operator   Nina_Gonzales610@iatim.tech      Nina Gonzales
# 1   2              Inspector     Dakota_Rose6376@atink.com        Dakota Rose
# 2   3  Healthcare Specialist  Caleb_Ballard1884@sveldo.biz      Caleb Ballard
# 3   4         HR Coordinator  Adeline_Selby3048@elnee.tech      Adeline Selby
# 4   5              Treasurer   Adela_Farmer1000@gembat.biz       Adela Farmer
#
#   Date And Time      last
# 0     6/21/9896  Gonzales
# 1      9/6/9482      Rose
# 2     5/15/4609   Ballard
# 3      7/5/3959     Selby
# 4     4/10/2671    Farmer
